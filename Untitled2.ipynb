# %% [markdown]
# <a href="https://colab.research.google.com/github/kuppanagariadithya-boop/Sales-DashBoard-analysis/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UPLOAD DATASET

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c8f6b87b-bef3-4742-9dcd-1ecdbc6a91f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8f6b87b-bef3-4742-9dcd-1ecdbc6a91f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# LOAD DATASET

# %%
import pandas as pd

df = pd.read_csv("Sales Dashboard Analysis (1).txt")
df.head()
# Out:
#    OrderID        Date Region         Category Product  Sales  Quantity  \
# 0     1001  2023-01-05   East       Technology  Laptop   1200         2
# 1     1002  2023-01-07   West        Furniture   Chair    300         5
# 2     1003  2023-01-10  South  Office Supplies     Pen     50        20
# 3     1004  2023-02-12  North       Technology  Mobile    800         3
# 4     1005  2023-02-18   East        Furniture   Table    600         2
#
#    Profit
# 0     200
# 1      50
# 2      10
# 3     150
# 4     120

# %% [markdown]
# DATA CLEANING

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.dropna()

df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %% [markdown]
# KPI CALCULATIONS

# %%
print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())
print("Total Orders:", len(df))
# Out:
# Total Sales: 14290
# Total Profit: 2788
# Total Orders: 24

# %% [markdown]
# GROUPING DATA

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
print(region_sales)
# Out:
# Region
# East     4440
# South    3680
# North    3360
# West     2810
# Name: Sales, dtype: int64

# %%
category_sales = df.groupby('Category')['Sales'].sum()
print(category_sales)
# Out:
# Category
# Furniture          8450
# Office Supplies     770
# Technology         5070
# Name: Sales, dtype: int64

# %%
monthly_sales = df.groupby(['Year','Month'])['Sales'].sum()
print(monthly_sales)
# Out:
# Year  Month
# 2023  1        1550
#       2        1400
#       3         700
#       4        1600
#       5        2250
#       6         850
#       7         980
#       8        1920
#       9         460
#       10        740
#       11       1750
#       12         90
# Name: Sales, dtype: int64

# %% [markdown]
# VISUALIZATIONS

# %%
import matplotlib.pyplot as plt

# Sales by Region
df.groupby('Region')['Sales'].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# Sales by Category
df.groupby('Category')['Sales'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales by Category")
plt.show()

# Monthly Trend
df.groupby('Month')['Sales'].sum().plot()
plt.title("Monthly Sales Trend")
plt.show()
